# %%
import numpy as np
import pandas as pd
from credentials import get_token
import matplotlib.pyplot as plt
from entsoe import EntsoePandasClient
from entsoe.mappings import TIMEZONE_MAPPINGS


country_code = 'GR'
client = EntsoePandasClient(api_key=get_token())
start = pd.Timestamp('20200101', tz=TIMEZONE_MAPPINGS[country_code])
end = pd.Timestamp('20200805', tz=TIMEZONE_MAPPINGS[country_code])

df = client.query_generation(country_code, start=start,end=end, psr_type=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5183 entries, 2020-01-01 00:00:00+02:00 to 2020-08-04 01:00:00+03:00
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fossil Brown coal/Lignite  5180 non-null   float64
#  1   Fossil Gas                 5180 non-null   float64
#  2   Fossil Oil                 5180 non-null   float64
#  3   Hydro Pumped Storage       5176 non-null   float64
#  4   Hydro Water Reservoir      5180 non-null   float64
#  5   Solar                      5183 non-null   float64
#  6   Wind Onshore               5183 non-null   float64
# dtypes: float64(7)
# memory usage: 323.9 KB

# %%
cols = ['Solar', 'Wind Onshore', 'Wind Offshore']

df['20200801':'20200804'].plot(figsize=(20,10))
plt.show()
